# %%
# Load packages:
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats
import matplotlib.pyplot as plt
from itertools import combinations
from scipy.stats import chi2_contingency
from scipy.stats import pointbiserialr
import statsmodels.formula.api as smf
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Aim of the analysis:
#
# The aim of the analysis is to predict the probability that the majority of alerts are critical or not given the state of the train. To do so, several classification algorithms are applied to data and the best classifier is chosen according to performance measures.
#
# Scenario: who employ the algorithm has few info on log data, such as only how many alerts/warnings, speed, n. of services ... but no info on which specific event occurred/is occurring

# %%
# Load dataset:
df = pd.read_parquet('..//..//Final_dataset//TSR_040_daily_PDM.parquet', engine='fastparquet')
df = df[(df['Time'] > '2020-08-28') & (df['Time'] < '2023/01/25')]
df = df.reset_index(drop=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 64 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Time                   580 non-null    datetime64[ns]
#  1   Source_mode            580 non-null    category
#  2   Source_711-083         580 non-null    int64
#  3   Source_711-084         580 non-null    int64
#  4   Name_mode              580 non-null    category
#  5   Name_710-131           580 non-null    int64
#  6   Name_710-132           580 non-null    int64
#  7   Name_710-135           580 non-null    int64
#  8   Name_710-170           580 non-null    int64
#  9   Name_711-083           580 non-null    int64
#  10  Name_711-084           580 non-null    int64
#  11  Type_mode              580 non-null    category
#  12  Type_PDM               580 non-null    int64
#  13  Type_TRAIN_DRIVER      580 non-null    int64
#  14  Type_WARNING           580 non-null    int64
#  15  Complete_code_mode     580 non-null    category
#  16  Complete_code_2-19     580 non-null    int64
#  17  Complete_code_5-1      580 non-null    int64
#  18  Complete_code_5-10     580 non-null    int64
#  19  Complete_code_5-11     580 non-null    int64
#  20  Complete_code_5-12     580 non-null    int64
#  21  Complete_code_5-13     580 non-null    int64
#  22  Complete_code_5-14     580 non-null    int64
#  23  Complete_code_5-15     580 non-null    int64
#  24  Complete_code_5-16     580 non-null    int64
#  25  Complete_code_5-17     580 non-null    int64
#  26  Complete_code_5-20     580 non-null    int64
#  27  Complete_code_5-21     580 non-null    int64
#  28  Complete_code_5-3      580 non-null    int64
#  29  Complete_code_5-31     580 non-null    int64
#  30  Complete_code_5-32     580 non-null    int64
#  31  Complete_code_5-33     580 non-null    int64
#  32  Complete_code_5-34     580 non-null    int64
#  33  Complete_code_5-35     580 non-null    int64
#  34  Complete_code_5-36     580 non-null    int64
#  35  Complete_code_5-5      580 non-null    int64
#  36  Complete_code_5-7      580 non-null    int64
#  37  Complete_code_5-9      580 non-null    int64
#  38  Complete_code_5-90     580 non-null    int64
#  39  Complete_code_5-98     580 non-null    int64
#  40  Complete_code_5-99     580 non-null    int64
#  41  Master_mode            580 non-null    category
#  42  Master_711-083         580 non-null    int64
#  43  Master_Master Assente  580 non-null    int64
#  44  Master_711-084         580 non-null    int64
#  45  Speed_mean             580 non-null    float64
#  46  Criticality_mode       580 non-null    category
#  47  Criticality_ratio      580 non-null    float64
#  48  Criticality_0          580 non-null    int64
#  49  Criticality_1          580 non-null    int64
#  50  Colour_mode            580 non-null    category
#  51  Colour_azzurro         580 non-null    int64
#  52  Colour_giallo          580 non-null    int64
#  53  Season                 580 non-null    category
#  54  Services               580 non-null    int64
#  55  Total_KM               580 non-null    float64
#  56  R4_progr_count         580 non-null    int64
#  57  RD_progr_count         580 non-null    int64
#  58  RP_progr_count         580 non-null    int64
#  59  RT_progr_count         580 non-null    int64
#  60  VI_progr_count         580 non-null    int64
#  61  VIS_progr_count        580 non-null    int64
#  62  Sched_maint_progr      580 non-null    int64
#  63  Corr_maint_progr       580 non-null    int64
# dtypes: category(8), datetime64[ns](1), float64(3), int64(52)
# memory usage: 258.8 KB
# None

# %%
# Drop columns out of interest:
#   -Time because it's not a time series and can't be used as a predictor
#   -Type_mode because every day assumes only 1 value of its 3 labels
#   -Complete_code due to data leakage (and assumption of the problem statement)
#   -Master because is not useful (compared to source or name)
#   -Criticality_ratio and 0,1 because are the same as Criticality_mode (which is the dependent variable)
#   -Count of each type of scheduled maintenances because some of them have only 1 value (the progressive count version of the variable has been created due to this)

#print(df.columns)
data = df.drop(columns=(['Time','Type_mode', 'Complete_code_mode',
       'Complete_code_2-19', 'Complete_code_5-1', 'Complete_code_5-10',
       'Complete_code_5-11', 'Complete_code_5-12', 'Complete_code_5-13',
       'Complete_code_5-14', 'Complete_code_5-15', 'Complete_code_5-16',
       'Complete_code_5-17', 'Complete_code_5-20', 'Complete_code_5-21',
       'Complete_code_5-3', 'Complete_code_5-31', 'Complete_code_5-32',
       'Complete_code_5-33', 'Complete_code_5-34', 'Complete_code_5-35',
       'Complete_code_5-36', 'Complete_code_5-5', 'Complete_code_5-7',
       'Complete_code_5-9', 'Complete_code_5-90', 'Complete_code_5-98',
       'Complete_code_5-99','Master_mode','Master_711-083','Master_Master Assente','Master_711-084', 'Criticality_ratio', 'Criticality_0', 'Criticality_1','R4_progr_count','RD_progr_count','RP_progr_count','RT_progr_count','VI_progr_count','VIS_progr_count']))
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Source_mode        580 non-null    category
#  1   Source_711-083     580 non-null    int64
#  2   Source_711-084     580 non-null    int64
#  3   Name_mode          580 non-null    category
#  4   Name_710-131       580 non-null    int64
#  5   Name_710-132       580 non-null    int64
#  6   Name_710-135       580 non-null    int64
#  7   Name_710-170       580 non-null    int64
#  8   Name_711-083       580 non-null    int64
#  9   Name_711-084       580 non-null    int64
#  10  Type_PDM           580 non-null    int64
#  11  Type_TRAIN_DRIVER  580 non-null    int64
#  12  Type_WARNING       580 non-null    int64
#  13  Speed_mean         580 non-null    float64
#  14  Criticality_mode   580 non-null    category
#  15  Colour_mode        580 non-null    category
#  16  Colour_azzurro     580 non-null    int64
#  17  Colour_giallo      580 non-null    int64
#  18  Season             580 non-null    category
#  19  Services           580 non-null    int64
#  20  Total_KM           580 non-null    float64
#  21  Sched_maint_progr  580 non-null    int64
#  22  Corr_maint_progr   580 non-null    int64
# dtypes: category(5), float64(2), int64(16)
# memory usage: 84.7 KB
# None

# %% [markdown]
# ### EDA
#
# Firstly, relationships among variables are studied in order to develop the predictive model. Conditional distributions of X given the two classes of the Y are plotted and studied, correlation analysis is performed and interaction terms are studied as well

# %% [markdown]
# #### 1) Dependent variable Y --> Criticality_mode

# %%
# check the Y variable:
y_var = data['Criticality_mode']
print(y_var.value_counts())
print("\n")
print(f"How many times = 0?: {y_var.value_counts()[0]} --> {y_var.value_counts()[0]/len(y_var)}")
print(f"How many times = 1?: {y_var.value_counts()[1]} --> {y_var.value_counts()[1]/len(y_var)}")
y_var.value_counts(normalize=True)        # to obtain the same as above but easely

# there is strong imbalance between the 2 classes! 98% mode=0 vs 2% mode=1
# the minority class, which is the positive class 1, is the one the classifier has to predict and the majority class is the negative class 0
# Out:
# Criticality_mode
# 0    568
# 1     12
# Name: count, dtype: int64
#
#
# How many times = 0?: 568 --> 0.9793103448275862
# How many times = 1?: 12 --> 0.020689655172413793
# Criticality_mode
# 0    0.97931
# 1    0.02069
# Name: proportion, dtype: float64

# %% [markdown]
# #### 2) Relationships between predictors X:
#
# In order to evaluate the multicollinearity possibly existing if all covariates are included in the model, correlation measures are computed between all the X variables.
#
# Perfect collinearity is expected between Source and Name or between Services and Total_KM as they represent the same info.
#
# Depending on the type of variables, an appropriate association measure is used:
# - pearson corr coeff for continuous-continuous
# - spearman rank corr coeff for count-count and for continuous-count
# - chi-square test for categorical-categorical and for categorical-count
# - point biserial correlation (or t-test or kruskall wallis test) for continuous-categorical

# %%
# define X's types:
#print(data.columns)
x_contin = ['Speed_mean', 'Total_KM']
x_count = ['Source_711-083', 'Source_711-084', 'Name_710-131', 'Name_710-132', 'Name_710-135', 'Name_710-170', 'Name_711-083', 'Name_711-084', 'Type_PDM', 'Type_TRAIN_DRIVER', 'Type_WARNING', 'Colour_azzurro', 'Colour_giallo', 'Services', 'Sched_maint_progr', 'Corr_maint_progr']
x_cat = ['Source_mode', 'Name_mode', 'Colour_mode', 'Season']

# %%
# between continuous variables:
print(scipy.stats.pearsonr(data[x_contin[0]], data[x_contin[1]]))
print("\n")
print(data[x_contin].corr())

plt.scatter(data[x_contin[0]], data[x_contin[1]])

# to note: 
#      p-value for testing non-correlation (H0 states the variables are not correlated while H1 they are correlated) --> p-value<0.05 so reject the null, which means they are correlated
#      pearson corr coeff ranges from 0 to 1
# Out:
# PearsonRResult(statistic=0.47264431119174777, pvalue=1.2939629402989943e-33)
#
#
#             Speed_mean  Total_KM
# Speed_mean    1.000000  0.472644
# Total_KM      0.472644  1.000000

# %%
# between count variables:
spearman_corr_matrix = data[x_count].corr(method='spearman')
mask = np.triu(np.ones_like(spearman_corr_matrix, dtype=bool))
corr_matrix_truncated = spearman_corr_matrix.mask(mask)
corr_matrix_truncated
high_corr = corr_matrix_truncated.abs() > 0.8
corr_matrix_truncated[high_corr]

# to note: spearman rank coeff ranges from -1 to 1

# corr>0.8 in abs value are:
#      source_084-type_pdm
#      source_084-colour_giallo
#      source_084-colour_azzurro
#      type_pdm-colour_giallo
#      type_pdm-colour_azzurro
#      sched_maint-correct_maint

# conclusions:
#      pretty high corr between counts of source and counts of name
#      pretty high corr between counts of name and type_pdm
#      pretty high corr between counts of name and counts of colour
# Out:
#                    Source_711-083  Source_711-084  Name_710-131  Name_710-132  \
# Source_711-083                NaN             NaN           NaN           NaN
# Source_711-084                NaN             NaN           NaN           NaN
# Name_710-131                  NaN             NaN           NaN           NaN
# Name_710-132                  NaN        0.853616           NaN           NaN
# Name_710-135                  NaN             NaN           NaN           NaN
# Name_710-170                  NaN        0.850255           NaN           NaN
# Name_711-083             0.833433             NaN           NaN           NaN
# Name_711-084                  NaN             NaN           NaN           NaN
# Type_PDM                      NaN        0.912488           NaN           NaN
# Type_TRAIN_DRIVER             NaN             NaN           NaN           NaN
# Type_WARNING                  NaN             NaN           NaN           NaN
# Colour_azzurro                NaN        0.877003           NaN           NaN
# Colour_giallo                 NaN        0.841988           NaN           NaN
# Services                      NaN             NaN           NaN           NaN
# Sched_maint_progr             NaN             NaN           NaN           NaN
# Corr_maint_progr              NaN             NaN           NaN           NaN
#
#                    Name_710-135  Name_710-170  Name_711-083  Name_711-084  \
# Source_711-083              NaN           NaN           NaN           NaN
# Source_711-084              NaN           NaN           NaN           NaN
# Name_710-131                NaN           NaN           NaN           NaN
# Name_710-132                NaN           NaN           NaN           NaN
# Name_710-135                NaN           NaN           NaN           NaN
# Name_710-170                NaN           NaN           NaN           NaN
# Name_711-083                NaN           NaN           NaN           NaN
# Name_711-084                NaN           NaN           NaN           NaN
# Type_PDM                    NaN           NaN           NaN           NaN
# Type_TRAIN_DRIVER           NaN           NaN           NaN           NaN
# Type_WARNING                NaN           NaN           NaN           NaN
# Colour_azzurro              NaN           NaN           NaN           NaN
# Colour_giallo               NaN           NaN           NaN           NaN
# Services                    NaN           NaN           NaN           NaN
# Sched_maint_progr           NaN           NaN           NaN           NaN
# Corr_maint_progr            NaN           NaN           NaN           NaN
#
#                    Type_PDM  Type_TRAIN_DRIVER  Type_WARNING  Colour_azzurro  \
# Source_711-083          NaN                NaN           NaN             NaN
# Source_711-084          NaN                NaN           NaN             NaN
# Name_710-131            NaN                NaN           NaN             NaN
# Name_710-132            NaN                NaN           NaN             NaN
# Name_710-135            NaN                NaN           NaN             NaN
# Name_710-170            NaN                NaN           NaN             NaN
# Name_711-083            NaN                NaN           NaN             NaN
# Name_711-084            NaN                NaN           NaN             NaN
# Type_PDM                NaN                NaN           NaN             NaN
# Type_TRAIN_DRIVER       NaN                NaN           NaN             NaN
# Type_WARNING            NaN                NaN           NaN             NaN
# Colour_azzurro     0.971638                NaN           NaN             NaN
# Colour_giallo      0.866555                NaN           NaN             NaN
# Services                NaN                NaN           NaN             NaN
# Sched_maint_progr       NaN                NaN           NaN             NaN
# Corr_maint_progr        NaN                NaN           NaN             NaN
#
#                    Colour_giallo  Services  Sched_maint_progr  \
# Source_711-083               NaN       NaN                NaN
# Source_711-084               NaN       NaN                NaN
# Name_710-131                 NaN       NaN                NaN
# Name_710-132                 NaN       NaN                NaN
# Name_710-135                 NaN       NaN                NaN
# Name_710-170                 NaN       NaN                NaN
# Name_711-083                 NaN       NaN                NaN
# Name_711-084                 NaN       NaN                NaN
# Type_PDM                     NaN       NaN                NaN
# Type_TRAIN_DRIVER            NaN       NaN                NaN
# Type_WARNING                 NaN       NaN                NaN
# Colour_azzurro               NaN       NaN                NaN
# Colour_giallo                NaN       NaN                NaN
# Services                     NaN       NaN                NaN
# Sched_maint_progr            NaN       NaN                NaN
# Corr_maint_progr             NaN       NaN           0.964036
#
#                    Corr_maint_progr
# Source_711-083                  NaN
# Source_711-084                  NaN
# Name_710-131                    NaN
# Name_710-132                    NaN
# Name_710-135                    NaN
# Name_710-170                    NaN
# Name_711-083                    NaN
# Name_711-084                    NaN
# Type_PDM                        NaN
# Type_TRAIN_DRIVER               NaN
# Type_WARNING                    NaN
# Colour_azzurro                  NaN
# Colour_giallo                   NaN
# Services                        NaN
# Sched_maint_progr               NaN
# Corr_maint_progr                NaN

# %%
# between categorical variables:
pairs = list(combinations(x_cat, 2))
print(pairs)
print("\n")

def perform_chi_square_test(data, pairs):
       contingency_table = pd.crosstab(data[pairs[0]], data[pairs[1]])
       chi2, p, dof, expected = chi2_contingency(contingency_table)
       n = contingency_table.sum().sum()  # total number of observations
       cramers_v = np.sqrt(chi2 / (n * (min(contingency_table.shape) - 1)))
       significant = p < 0.05  # 5% significance level
       return pairs, chi2, p, significant, cramers_v

for pair in pairs:
       print(perform_chi_square_test(data, pair))

# to note:
#      null hypothesis (H0) which states that there is no relation between the variables and alternative hypothesis (H1) which states there is a significant relationship between the two variables
#      cramer's V is used to measure the strength of association between two categorical variables and ranges from 0 to 1

# conclusions: just source_mode and name_mode are pretty much strong
# Out:
# [('Source_mode', 'Name_mode'), ('Source_mode', 'Colour_mode'), ('Source_mode', 'Season'), ('Name_mode', 'Colour_mode'), ('Name_mode', 'Season'), ('Colour_mode', 'Season')]
#
#
# (('Source_mode', 'Name_mode'), 237.20306344669402, 3.0548472112864503e-49, True, 0.6395082478326798)
# (('Source_mode', 'Colour_mode'), 20.58412763394469, 5.706730118260698e-06, True, 0.18838756655081862)
# (('Source_mode', 'Season'), 8.206841785833959, 0.04192484464442746, True, 0.1189526259355173)
# (('Name_mode', 'Colour_mode'), 64.3257334996882, 1.5464396990647363e-12, True, 0.3330261807552492)
# (('Name_mode', 'Season'), 51.30039123466347, 7.3683260242749535e-06, True, 0.1717060961882175)
# (('Colour_mode', 'Season'), 20.6171298974358, 0.0001264187545502172, True, 0.18853852573210106)

# %%
# between continuous and count variables:
x_count_contin = x_count+x_contin
print(x_count_contin)
spearman_corr_matrix = data[x_count_contin].corr(method='spearman')
mask = np.triu(np.ones_like(spearman_corr_matrix, dtype=bool))
corr_matrix_truncated = spearman_corr_matrix.mask(mask)
corr_matrix_truncated
#high_corr = corr_matrix_truncated.abs() > 0.8
#corr_matrix_truncated[high_corr]

# conclusions: any strong association between the continuous and counts variables
# Out:
# ['Source_711-083', 'Source_711-084', 'Name_710-131', 'Name_710-132', 'Name_710-135', 'Name_710-170', 'Name_711-083', 'Name_711-084', 'Type_PDM', 'Type_TRAIN_DRIVER', 'Type_WARNING', 'Colour_azzurro', 'Colour_giallo', 'Services', 'Sched_maint_progr', 'Corr_maint_progr', 'Speed_mean', 'Total_KM']
#                    Source_711-083  Source_711-084  Name_710-131  Name_710-132  \
# Source_711-083                NaN             NaN           NaN           NaN
# Source_711-084           0.347475             NaN           NaN           NaN
# Name_710-131             0.578009        0.188588           NaN           NaN
# Name_710-132             0.280903        0.853616      0.160174           NaN
# Name_710-135             0.712629        0.361417      0.265437      0.291670
# Name_710-170             0.318326        0.850255      0.189344      0.594318
# Name_711-083             0.833433        0.280960      0.234917      0.246153
# Name_711-084             0.327048        0.793421      0.116272      0.604109
# Type_PDM                 0.657052        0.912488      0.358898      0.773241
# Type_TRAIN_DRIVER        0.100336        0.212899      0.124196      0.135714
# Type_WARNING             0.067993        0.505355      0.061167      0.478854
# Colour_azzurro           0.653636        0.877003      0.331260      0.726803
# Colour_giallo            0.525618        0.841988      0.358846      0.759198
# Services                 0.302781        0.320401      0.171127      0.243946
# Sched_maint_progr       -0.177454        0.274737     -0.283747      0.351617
# Corr_maint_progr        -0.158406        0.271344     -0.203978      0.347083
# Speed_mean               0.105899        0.299990      0.061803      0.217934
# Total_KM                 0.255089        0.459748      0.103543      0.313890
#
#                    Name_710-135  Name_710-170  Name_711-083  Name_711-084  \
# Source_711-083              NaN           NaN           NaN           NaN
# Source_711-084              NaN           NaN           NaN           NaN
# Name_710-131                NaN           NaN           NaN           NaN
# Name_710-132                NaN           NaN           NaN           NaN
# Name_710-135                NaN           NaN           NaN           NaN
# Name_710-170           0.312111           NaN           NaN           NaN
# Name_711-083           0.505034      0.232850           NaN           NaN
# Name_711-084           0.342260      0.559687      0.299227           NaN
# Type_PDM               0.546620      0.779577      0.551489      0.745465
# Type_TRAIN_DRIVER      0.117009      0.167625      0.063243      0.251244
# Type_WARNING           0.041773      0.422927      0.020078      0.402477
# Colour_azzurro         0.490725      0.775247      0.573979      0.721609
# Colour_giallo          0.560990      0.675813      0.379929      0.692734
# Services               0.342646      0.316405      0.229381      0.319439
# Sched_maint_progr     -0.062999      0.218830     -0.085411      0.097659
# Corr_maint_progr      -0.068913      0.217710     -0.108712      0.088244
# Speed_mean             0.247634      0.354657      0.090414      0.169559
# Total_KM               0.276047      0.507799      0.239934      0.355705
#
#                    Type_PDM  Type_TRAIN_DRIVER  Type_WARNING  Colour_azzurro  \
# Source_711-083          NaN                NaN           NaN             NaN
# Source_711-084          NaN                NaN           NaN             NaN
# Name_710-131            NaN                NaN           NaN             NaN
# Name_710-132            NaN                NaN           NaN             NaN
# Name_710-135            NaN                NaN           NaN             NaN
# Name_710-170            NaN                NaN           NaN             NaN
# Name_711-083            NaN                NaN           NaN             NaN
# Name_711-084            NaN                NaN           NaN             NaN
# Type_PDM                NaN                NaN           NaN             NaN
# Type_TRAIN_DRIVER  0.188082                NaN           NaN             NaN
# Type_WARNING       0.399169           0.134958           NaN             NaN
# Colour_azzurro     0.971638           0.198695      0.421613             NaN
# Colour_giallo      0.866555           0.188702      0.357567        0.739394
# Services           0.360418           0.203034      0.130184        0.357120
# Sched_maint_progr  0.136525          -0.152004      0.263863        0.106055
# Corr_maint_progr   0.137090          -0.154024      0.279999        0.101368
# Speed_mean         0.248633           0.052594      0.066304        0.232446
# Total_KM           0.440193           0.150759      0.158490        0.450839
#
#                    Colour_giallo  Services  Sched_maint_progr  \
# Source_711-083               NaN       NaN                NaN
# Source_711-084               NaN       NaN                NaN
# Name_710-131                 NaN       NaN                NaN
# Name_710-132                 NaN       NaN                NaN
# Name_710-135                 NaN       NaN                NaN
# Name_710-170                 NaN       NaN                NaN
# Name_711-083                 NaN       NaN                NaN
# Name_711-084                 NaN       NaN                NaN
# Type_PDM                     NaN       NaN                NaN
# Type_TRAIN_DRIVER            NaN       NaN                NaN
# Type_WARNING                 NaN       NaN                NaN
# Colour_azzurro               NaN       NaN                NaN
# Colour_giallo                NaN       NaN                NaN
# Services                0.336752       NaN                NaN
# Sched_maint_progr       0.187798 -0.101416                NaN
# Corr_maint_progr        0.202790 -0.108013           0.964036
# Speed_mean              0.260846  0.197544           0.030470
# Total_KM                0.367863  0.488982           0.032120
#
#                    Corr_maint_progr  Speed_mean  Total_KM
# Source_711-083                  NaN         NaN       NaN
# Source_711-084                  NaN         NaN       NaN
# Name_710-131                    NaN         NaN       NaN
# Name_710-132                    NaN         NaN       NaN
# Name_710-135                    NaN         NaN       NaN
# Name_710-170                    NaN         NaN       NaN
# Name_711-083                    NaN         NaN       NaN
# Name_711-084                    NaN         NaN       NaN
# Type_PDM                        NaN         NaN       NaN
# Type_TRAIN_DRIVER               NaN         NaN       NaN
# Type_WARNING                    NaN         NaN       NaN
# Colour_azzurro                  NaN         NaN       NaN
# Colour_giallo                   NaN         NaN       NaN
# Services                        NaN         NaN       NaN
# Sched_maint_progr               NaN         NaN       NaN
# Corr_maint_progr                NaN         NaN       NaN
# Speed_mean                 0.004046         NaN       NaN
# Total_KM                   0.022548    0.472987       NaN

# %%
# between categorical and count variables:
x_cat_count = x_cat+x_count
#print(x_cat_count)
pairs = list(combinations(x_cat_count, 2))
#print(pairs)
print("\n")
for pair in pairs:
       if perform_chi_square_test(data, pair)[4]>0.7:
              print(perform_chi_square_test(data, pair))

# conclusions:
#      strong association between season and sched_maint
#      pretty high association between source_mode and type_pdm , source_mode and colour_azzurro, colour_mode and type_pdm
# Out:
# (('Source_mode', 'Source_711-084'), 329.35391465677174, 7.902755736036667e-08, True, 0.753559272383025)
# (('Source_mode', 'Type_PDM'), 320.07997251425826, 0.0003542732443433861, True, 0.7428741626791898)
# (('Source_mode', 'Colour_azzurro'), 290.5938294509723, 3.604447687708613e-05, True, 0.7078303779020697)
# (('Colour_mode', 'Source_711-084'), 292.0508937227202, 6.164761105487041e-05, True, 0.709602722415763)
# (('Colour_mode', 'Type_PDM'), 330.82483392080917, 7.61585220379184e-05, True, 0.7552401238619744)
# (('Season', 'Sched_maint_progr'), 1315.4288118240981, 2.2196022235483157e-248, True, 0.8694789071701794)
# (('Source_711-084', 'Name_710-132'), 27940.808841687412, 0.0, True, 0.7158821990022276)
# (('Source_711-084', 'Name_711-084'), 26812.044354063823, 0.0, True, 0.7166873072951719)
# (('Source_711-084', 'Type_TRAIN_DRIVER'), 3299.8590603237344, 6.534447503458957e-62, True, 0.7542819216295692)
# (('Name_710-131', 'Type_PDM'), 17928.633379775125, 2.6912825213988773e-98, True, 0.7238250193745471)
# (('Name_710-131', 'Colour_azzurro'), 16917.38238640639, 3.188315051494394e-186, True, 0.7031153516546961)
# (('Name_710-132', 'Type_PDM'), 27868.742705200442, 2.078531933314791e-124, True, 0.7149583858465502)
# (('Name_711-084', 'Type_PDM'), 28856.24800476782, 1.4649677679163436e-225, True, 0.7435063455782286)
# (('Type_PDM', 'Type_TRAIN_DRIVER'), 2904.157640065249, 1.5707869590916207e-12, True, 0.707613478174355)
# (('Type_PDM', 'Type_WARNING'), 5616.315117307246, 4.070808981986949e-26, True, 0.7138959796847821)
# (('Type_PDM', 'Colour_azzurro'), 59288.444463340886, 1.1562010470290951e-250, True, 0.7131370538462745)
# (('Type_PDM', 'Colour_giallo'), 33209.03984073686, 1.1451307499422734e-183, True, 0.7247711770668578)
# (('Sched_maint_progr', 'Corr_maint_progr'), 3210.326321929767, 0.0, True, 0.7439788560596012)

# %%
# between continuous and categorical variables:
# a) binary --> point biserial correlation:
print(x_cat)
print(x_contin)
source_numeric = np.where(data[x_cat[0]] == '711-083', 0, 1)
colour_numeric = np.where(data[x_cat[2]] == 'azzurro', 0, 1)
print(f"Source_mode and Speed_mean: {pointbiserialr(data[x_contin[0]], source_numeric)}")
print(f"Source_mode and Total_KM: {pointbiserialr(data[x_contin[1]], source_numeric)}")
print(f"Colour_mode and Speed_mean: {pointbiserialr(data[x_contin[0]], colour_numeric)}")
print(f"Colour_mode and Total_KM: {pointbiserialr(data[x_contin[1]], colour_numeric)}")

# to note: point biserial correlation ranges from -1 to 1
# conclusion: any association

# b) categorical nominal --> boxplots
sns.boxplot(x=data[x_cat[1]], y=data[x_contin[0]], data=data)
plt.show()
sns.boxplot(x=data[x_cat[1]], y=data[x_contin[1]], data=data)
plt.show()
sns.boxplot(x=data[x_cat[3]], y=data[x_contin[0]], data=data)
plt.show()
sns.boxplot(x=data[x_cat[3]], y=data[x_contin[1]], data=data)
plt.show()

# conclusions: any particular changes for any pairs
# Out:
# ['Source_mode', 'Name_mode', 'Colour_mode', 'Season']
# ['Speed_mean', 'Total_KM']
# Source_mode and Speed_mean: SignificanceResult(statistic=0.09588572774833498, pvalue=0.020911636542936343)
# Source_mode and Total_KM: SignificanceResult(statistic=0.0742921104621456, pvalue=0.07380790867656385)
# Colour_mode and Speed_mean: SignificanceResult(statistic=-0.12038995689862397, pvalue=0.0036879675037419565)
# Colour_mode and Total_KM: SignificanceResult(statistic=-0.092265826667594, pvalue=0.02628309366670938)

# %% [markdown]
# #### 3) Draft of relationship between Y and numerical variables X
#
# 2 ways:
# - association measures to get an idea of association between Y and X variables --> needed for classifiers which can't directly handle curse of dimensionality (logistic, knn, svm), while trees and ensemble methods implicity perform feature selection when deciding which predictor to use for each split
# - significance and impact of each single X on Y --> it can be done only for logistic regression
#
# In order to understand which are the candidates to be predictors of a logistic regression, marginal correlation coefficients can be used for exploratory analysis to seek candidates predictors, which means fitting a marginal model for each predictor. The point is that if a predictor results here NOT significant, it is very unlikely that it can impact in the multiple model (bog model), but on the other hand, if it is significant it could not be the same in the big model!
#
# To note that here a bias is arbitrary included as the imbalamce problem is not handled and the dataset is not splitted into train and test

# %%
# 1) association between Y and each X:
print(x_cat)
print(x_contin)
print(x_count)
y = ['Criticality_mode']

# a) Y and count variables:
x_count_y = x_count+y
pairs = list(combinations(x_count_y, 2))
print("\n")
for pair in pairs:
       if 'Criticality_mode' in pair:
              print(perform_chi_square_test(data, pair))

# conclusion: more than weak association between Source_711-084, Type_PDM, Colour_azzurro


# b) Y and categorical variables:
x_cat_y = x_cat+y
pairs = list(combinations(x_cat_y, 2))
print("\n")
for pair in pairs:
       if 'Criticality_mode' in pair:
              print(perform_chi_square_test(data, pair))

# conclusion: more than weak association between Colour_mode


# c) Y and continuous variables --> no point biserial corr due to huge imbalance:
sns.boxplot(x=data['Criticality_mode'], y=data['Speed_mean'], data=data)
plt.show()
sns.boxplot(x=data['Criticality_mode'], y=data['Total_KM'], data=data)
plt.show()

# conclusion: it seems there are more difference between speed_mean while almost any between total_km
# Out:
# ['Source_mode', 'Name_mode', 'Colour_mode', 'Season']
# ['Speed_mean', 'Total_KM']
# ['Source_711-083', 'Source_711-084', 'Name_710-131', 'Name_710-132', 'Name_710-135', 'Name_710-170', 'Name_711-083', 'Name_711-084', 'Type_PDM', 'Type_TRAIN_DRIVER', 'Type_WARNING', 'Colour_azzurro', 'Colour_giallo', 'Services', 'Sched_maint_progr', 'Corr_maint_progr']
#
#
# (('Source_711-083', 'Criticality_mode'), 106.02844990168933, 0.7357558630896748, False, 0.42756013874575816)
# (('Source_711-084', 'Criticality_mode'), 222.65020679633358, 0.1892799851243922, False, 0.6195802344250745)
# (('Name_710-131', 'Criticality_mode'), 59.411502686150556, 0.4604978212112969, False, 0.32005253525155714)
# (('Name_710-132', 'Criticality_mode'), 112.57891365285732, 0.09296939270188673, False, 0.4405696031997068)
# (('Name_710-135', 'Criticality_mode'), 22.14637026445207, 0.998865823854523, False, 0.19540572409137863)
# (('Name_710-170', 'Criticality_mode'), 121.49013561425528, 0.10308298327899207, False, 0.4576742849003654)
# (('Name_711-083', 'Criticality_mode'), 33.90768913450267, 0.9999176838659395, False, 0.24178819861714063)
# (('Name_711-084', 'Criticality_mode'), 195.90051673678428, 7.821190969100194e-10, True, 0.5811708110488218)
# (('Type_PDM', 'Criticality_mode'), 344.97876145763473, 8.43229777363357e-06, True, 0.7712269238235947)
# (('Type_TRAIN_DRIVER', 'Criticality_mode'), 17.983401065152442, 0.055244288264595404, False, 0.17608482020161548)
# (('Type_WARNING', 'Criticality_mode'), 15.823978999583796, 0.6689881317962003, False, 0.16517482378702728)
# (('Colour_azzurro', 'Criticality_mode'), 324.6494243237202, 7.400856851612843e-08, True, 0.7481579958571818)
# (('Colour_giallo', 'Criticality_mode'), 164.93290763097104, 0.00043780559585346687, True, 0.5332608012242827)
# (('Services', 'Criticality_mode'), 20.811424431992663, 0.3473136210507015, False, 0.1894248301096145)
# (('Sched_maint_progr', 'Criticality_mode'), 47.822892743667396, 1.4063082834263815e-05, True, 0.2871467627384134)
# (('Corr_maint_progr', 'Criticality_mode'), 15.21207681773969, 0.12451909246171619, False, 0.16194974112753416)
#
#
# (('Source_mode', 'Criticality_mode'), 18.8632908562486, 1.4042921010492485e-05, True, 0.18034110809627998)
# (('Name_mode', 'Criticality_mode'), 66.82999090541324, 4.673835796723202e-13, True, 0.33944678854087346)
# (('Colour_mode', 'Criticality_mode'), 331.30149112456263, 5.0040601235555276e-74, True, 0.7557840084681221)
# (('Season', 'Criticality_mode'), 9.206445297172564, 0.026668352895932737, True, 0.12598881516566957)

# %%
# 2) marginal effects:

# a) change name to convert - in _ due to syntax issues:
data = data.rename(columns={'Source_711-083': 'Source_711_083'})
data = data.rename(columns={'Source_711-084': 'Source_711_084'})
data = data.rename(columns={'Name_710-131': 'Name_710_131'})
data = data.rename(columns={'Name_710-132': 'Name_710_132'})
data = data.rename(columns={'Name_710-135': 'Name_710_135'})
data = data.rename(columns={'Name_710-170': 'Name_710_170'})
data = data.rename(columns={'Name_711-083': 'Name_711_083'})
data = data.rename(columns={'Name_711-084': 'Name_711_084'})

# b) dependent and independent variables:
x = data.drop(columns=['Criticality_mode','Name_mode'], axis=1)     # name_mode is excluded due to singularity matrix!
print(x.info())
y = data['Criticality_mode'].astype('int64')    # convert into numerical dummy variable to be processed by the function

print("\n")
print(type(y))
for i in x:
    print(type(x[i]))
    print(x[i].shape)
print("\n")
print(y.shape)

# c) iterate over all X:
for i in x.columns:  # Iterate over column names
    if data[i].dtype == 'category':  # Check if the column is categorical to use notation "C()" which is the way to handle categorical variable --> it automatically exclude a category and use it as reference category
        formula = f'y ~ C({i})'
        print(f"Criticality_mode ~ {i}")
        model = smf.logit(formula, data=data)
        results = model.fit(disp=True)
        print(results.summary())
        print("\n")
    else:
        formula = f'y ~ {i}'
        print(f"Criticality_mode ~ {i}")
        model = smf.logit(formula, data=data)
        results = model.fit(disp=True)
        print(results.summary())
        print("\n")
        
# conclusion:
#   p-value>0.05 for Source_711_083, Name_710_131, Name_710_135, (gli altri name un po' al limite), Type_TRAIN_DRIVER, Type_WARNING, Speed_mean, Colour_mode (Maximum number of iterations has been exceeded and Possibly complete quasi-separation), Colour_giallo, 2 su 3 Season (Possibly complete quasi-separation), Services, Corr_maint_progr
#   p-value<0.05 for Source_mode, Source_711_084, Name_710_132, Name_710_170, Name_711_083, Name_711_084, Type_PDM, Colour_azzurro, Total_KM, Sched_maint_progr
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Source_mode        580 non-null    category
#  1   Source_711_083     580 non-null    int64
#  2   Source_711_084     580 non-null    int64
#  3   Name_710_131       580 non-null    int64
#  4   Name_710_132       580 non-null    int64
#  5   Name_710_135       580 non-null    int64
#  6   Name_710_170       580 non-null    int64
#  7   Name_711_083       580 non-null    int64
#  8   Name_711_084       580 non-null    int64
#  9   Type_PDM           580 non-null    int64
#  10  Type_TRAIN_DRIVER  580 non-null    int64
#  11  Type_WARNING       580 non-null    int64
#  12  Speed_mean         580 non-null    float64
#  13  Colour_mode        580 non-null    category
#  14  Colour_azzurro     580 non-null    int64
#  15  Colour_giallo      580 non-null    int64
#  16  Season             580 non-null    category
#  17  Services           580 non-null    int64
#  18  Total_KM           580 non-null    float64
#  19  Sched_maint_progr  580 non-null    int64
#  20  Corr_maint_progr   580 non-null    int64
# dtypes: category(3), float64(2), int64(16)
# memory usage: 83.8 KB
# None
#
#
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
# <class 'pandas.core.series.Series'>
# (580,)
#
#
# (580,)
# Criticality_mode ~ Source_mode
# Optimization terminated successfully.
#          Current function value: 0.089222
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                  0.1141
# Time:                        17:33:18   Log-Likelihood:                -51.749
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                 0.0002616
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -2.1001      0.433     -4.855      0.000      -2.948      -1.252
# C(Source_mode)[T.711-084]    -2.3601      0.596     -3.957      0.000      -3.529      -1.191
# =============================================================================================
#
#
# Criticality_mode ~ Source_711_083
# Optimization terminated successfully.
#          Current function value: 0.098385
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.02310
# Time:                        17:33:18   Log-Likelihood:                -57.063
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                    0.1005
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -3.2903      0.435     -7.571      0.000      -4.142      -2.439
# Source_711_083    -0.0197      0.014     -1.417      0.157      -0.047       0.008
# ==================================================================================
#
#
# Criticality_mode ~ Source_711_084
# Optimization terminated successfully.
#          Current function value: 0.089811
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                  0.1082
# Time:                        17:33:18   Log-Likelihood:                -52.090
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                 0.0003766
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -2.2110      0.470     -4.704      0.000      -3.132      -1.290
# Source_711_084    -0.0231      0.007     -3.099      0.002      -0.038      -0.008
# ==================================================================================
#
#
# Criticality_mode ~ Name_710_131
# Optimization terminated successfully.
#          Current function value: 0.100707
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:               3.761e-05
# Time:                        17:33:18   Log-Likelihood:                -58.410
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                    0.9472
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -3.8479      0.325    -11.827      0.000      -4.486      -3.210
# Name_710_131    -0.0009      0.014     -0.064      0.949      -0.029       0.027
# ================================================================================
#
#
# Criticality_mode ~ Name_710_132
# Optimization terminated successfully.
#          Current function value: 0.088043
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                  0.1258
# Time:                        17:33:18   Log-Likelihood:                -51.065
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                 0.0001264
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -2.3157      0.429     -5.393      0.000      -3.157      -1.474
# Name_710_132    -0.0837      0.028     -3.015      0.003      -0.138      -0.029
# ================================================================================
#
#
# Criticality_mode ~ Name_710_135
# Optimization terminated successfully.
#          Current function value: 0.100399
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                0.003103
# Time:                        17:33:18   Log-Likelihood:                -58.231
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                    0.5471
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -3.6910      0.395     -9.335      0.000      -4.466      -2.916
# Name_710_135    -0.0215      0.038     -0.567      0.571      -0.096       0.053
# ================================================================================
#
#
# Criticality_mode ~ Name_710_170
# Optimization terminated successfully.
#          Current function value: 0.094598
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.06070
# Time:                        17:33:18   Log-Likelihood:                -54.867
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                  0.007747
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -2.8204      0.440     -6.414      0.000      -3.682      -1.959
# Name_710_170    -0.0399      0.018     -2.276      0.023      -0.074      -0.006
# ================================================================================
#
#
# Criticality_mode ~ Name_711_083
# Optimization terminated successfully.
#          Current function value: 0.093761
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.06901
# Time:                        17:33:18   Log-Likelihood:                -54.382
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                  0.004521
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -3.0228      0.384     -7.871      0.000      -3.776      -2.270
# Name_711_083    -0.0844      0.042     -2.014      0.044      -0.167      -0.002
# ================================================================================
#
#
# Criticality_mode ~ Name_711_084
# Optimization terminated successfully.
#          Current function value: 0.092839
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.07817
# Time:                        17:33:18   Log-Likelihood:                -53.847
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                  0.002512
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -2.4187      0.492     -4.919      0.000      -3.382      -1.455
# Name_711_084    -0.0564      0.021     -2.709      0.007      -0.097      -0.016
# ================================================================================
#
#
# Criticality_mode ~ Type_PDM
# Optimization terminated successfully.
#          Current function value: 0.090464
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                  0.1018
# Time:                        17:33:18   Log-Likelihood:                -52.469
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                 0.0005652
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.1167      0.514     -4.120      0.000      -3.124      -1.110
# Type_PDM      -0.0177      0.006     -2.989      0.003      -0.029      -0.006
# ==============================================================================
#
#
# Criticality_mode ~ Type_TRAIN_DRIVER
# Optimization terminated successfully.
#          Current function value: 0.100569
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                0.001415
# Time:                        17:33:18   Log-Likelihood:                -58.330
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                    0.6843
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -3.7937      0.329    -11.532      0.000      -4.439      -3.149
# Type_TRAIN_DRIVER    -0.1129      0.303     -0.373      0.709      -0.707       0.481
# =====================================================================================
#
#
# Criticality_mode ~ Type_WARNING
# Optimization terminated successfully.
#          Current function value: 0.096638
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.04045
# Time:                        17:33:18   Log-Likelihood:                -56.050
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                   0.02972
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -3.3399      0.346     -9.640      0.000      -4.019      -2.661
# Type_WARNING    -0.3803      0.219     -1.735      0.083      -0.810       0.049
# ================================================================================
#
#
# Criticality_mode ~ Speed_mean
# Optimization terminated successfully.
#          Current function value: 0.098193
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.02500
# Time:                        17:33:18   Log-Likelihood:                -56.952
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                   0.08746
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.7026      0.685     -3.947      0.000      -4.045      -1.360
# Speed_mean    -0.0476      0.028     -1.673      0.094      -0.103       0.008
# ==============================================================================
#
#
# Criticality_mode ~ Colour_mode
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.021559
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                  0.7859
# Time:                        17:33:18   Log-Likelihood:                -12.504
# converged:                      False   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                 9.509e-22
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                  -20.6665   1297.784     -0.016      0.987   -2564.277    2522.943
# C(Colour_mode)[T.giallo]    21.2055   1297.784      0.016      0.987   -2522.405    2564.816
# ============================================================================================
#
# Possibly complete quasi-separation: A fraction 0.97 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#
#
# Criticality_mode ~ Colour_azzurro
# Optimization terminated successfully.
#          Current function value: 0.078469
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                  0.2209
# Time:                        17:33:18   Log-Likelihood:                -45.512
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                 3.785e-07
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -1.3641      0.483     -2.821      0.005      -2.312      -0.416
# Colour_azzurro    -0.0446      0.012     -3.829      0.000      -0.067      -0.022
# ==================================================================================
#
#
# Criticality_mode ~ Colour_giallo
# Optimization terminated successfully.
#          Current function value: 0.100624
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:               0.0008604
# Time:                        17:33:18   Log-Likelihood:                -58.362
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                    0.7512
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -3.7192      0.523     -7.114      0.000      -4.744      -2.695
# Colour_giallo    -0.0034      0.011     -0.309      0.757      -0.025       0.018
# =================================================================================
#
#
# Criticality_mode ~ Season
# Optimization terminated successfully.
#          Current function value: 0.090969
#          Iterations 28
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      576
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.09673
# Time:                        17:33:18   Log-Likelihood:                -52.762
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                   0.01021
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -4.9488      1.004     -4.931      0.000      -6.916      -2.982
# C(Season)[T.Spring]     1.3792      1.124      1.227      0.220      -0.824       3.583
# C(Season)[T.Summer]   -41.1153   8.57e+08   -4.8e-08      1.000   -1.68e+09    1.68e+09
# C(Season)[T.Winter]     1.9042      1.076      1.771      0.077      -0.204       4.012
# =======================================================================================
#
# Possibly complete quasi-separation: A fraction 0.24 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#
#
# Criticality_mode ~ Services
# Optimization terminated successfully.
#          Current function value: 0.098241
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.02453
# Time:                        17:33:18   Log-Likelihood:                -56.980
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                   0.09050
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.7456      0.641     -4.285      0.000      -4.001      -1.490
# Services      -0.1006      0.058     -1.748      0.081      -0.213       0.012
# ==============================================================================
#
#
# Criticality_mode ~ Total_KM
# Optimization terminated successfully.
#          Current function value: 0.096405
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.04276
# Time:                        17:33:18   Log-Likelihood:                -55.915
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                   0.02541
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.4990      0.587     -4.256      0.000      -3.650      -1.348
# Total_KM      -0.0037      0.002     -2.275      0.023      -0.007      -0.001
# ==============================================================================
#
#
# Criticality_mode ~ Sched_maint_progr
# Optimization terminated successfully.
#          Current function value: 0.097185
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.03501
# Time:                        17:33:18   Log-Likelihood:                -56.367
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                   0.04312
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -2.3542      0.756     -3.115      0.002      -3.836      -0.873
# Sched_maint_progr    -0.1351      0.071     -1.917      0.055      -0.273       0.003
# =====================================================================================
#
#
# Criticality_mode ~ Corr_maint_progr
# Optimization terminated successfully.
#          Current function value: 0.098763
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      578
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.01934
# Time:                        17:33:18   Log-Likelihood:                -57.283
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                    0.1328
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -2.3404      0.981     -2.387      0.017      -4.262      -0.418
# Corr_maint_progr    -0.1209      0.079     -1.523      0.128      -0.277       0.035
# ====================================================================================
# /home/jupyter-giulia/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
'''
# extra) singularity when x=Name_mode:
model = smf.logit('y ~ C(Name_mode)', data=data)  # Use the formula in the model
results = model.fit()
print(results.summary())

# possible problem: Insufficient Data Variation
'''
# Out:
# "\n# extra) singularity when x=Name_mode:\nmodel = smf.logit('y ~ C(Name_mode)', data=data)  # Use the formula in the model\nresults = model.fit()\nprint(results.summary())\n\n# possible problem: Insufficient Data Variation\n"

# %% [markdown]
# #### 4) Interaction terms
#
# 3 possible interaction terms are studied to understand if they can improve the prediction of the models:
# - type_pdm with colour_giallo
# - sched_maint with correct_maint
# - total_KM and type_PDM in order to handle with multimodal of total km
#
# Since decision trees are able to seek also interaction terms between predictors, this step is useful for the logistic model only

# %%
poly = PolynomialFeatures(interaction_only=True,include_bias = False)
x_int_1 = data[['Type_PDM','Colour_giallo']]
x_int_2 = data[['Sched_maint_progr','Corr_maint_progr']]
x_int_3 = data[['Total_KM','Type_PDM']]
inter_pdm_giallo = poly.fit_transform(x_int_1)
inter_sched_corr = poly.fit_transform(x_int_2)
inter_type_km = poly.fit_transform(x_int_3)

model = smf.logit('y ~ inter_pdm_giallo', data=data)
results = model.fit()
print(results.summary())

model = smf.logit('y ~ inter_sched_corr', data=data)
results = model.fit()
print(results.summary())

model = smf.logit('y ~ inter_type_km', data=data)
results = model.fit()
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.041668
#          Iterations 12
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      576
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                  0.5863
# Time:                        17:33:19   Log-Likelihood:                -24.168
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                 8.987e-15
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.8430      0.640     -1.316      0.188      -2.098       0.412
# inter_pdm_giallo[0]    -0.2339      0.060     -3.895      0.000      -0.352      -0.116
# inter_pdm_giallo[1]     0.4270      0.109      3.923      0.000       0.214       0.640
# inter_pdm_giallo[2] -4.276e-05      0.000     -0.404      0.686      -0.000       0.000
# =======================================================================================
#
# Possibly complete quasi-separation: A fraction 0.66 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# Optimization terminated successfully.
#          Current function value: 0.095036
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      576
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                 0.05635
# Time:                        17:33:19   Log-Likelihood:                -55.121
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                   0.08646
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.1408      2.936      0.048      0.962      -5.614       5.896
# inter_sched_corr[0]    -0.9888      0.581     -1.703      0.089      -2.127       0.149
# inter_sched_corr[1]     0.1114      0.242      0.460      0.645      -0.363       0.586
# inter_sched_corr[2]     0.0363      0.029      1.242      0.214      -0.021       0.093
# =======================================================================================
# Optimization terminated successfully.
#          Current function value: 0.087240
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  580
# Model:                          Logit   Df Residuals:                      576
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 01 Sep 2024   Pseudo R-squ.:                  0.1338
# Time:                        17:33:19   Log-Likelihood:                -50.599
# converged:                       True   LL-Null:                       -58.412
# Covariance Type:            nonrobust   LLR p-value:                  0.001352
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.9304      0.764     -1.218      0.223      -2.428       0.567
# inter_type_km[0]    -0.0035      0.002     -1.474      0.141      -0.008       0.001
# inter_type_km[1]    -0.0479      0.020     -2.405      0.016      -0.087      -0.009
# inter_type_km[2]  6.961e-05   3.69e-05      1.887      0.059    -2.7e-06       0.000
# ====================================================================================

# %% [markdown]
# Results of EDA:
# - about multicollinearity between variables that represent the same info (source-name, services-total km): source and tot km have been chosen to be used while name and services will be dropped from X vector and
# - about which version to use (count or mode for source, name, colour): count for colour and source have been chosen to be used
# - potential multicollinearity issue between predictors: it seems there could be this problem for source and type_pdm and colour, sched maint and corr maint, season and sched maint
# - only interaction between total_km and type_pdm will be considered in the model --> p.s.: from results of logistic with the interaction and without, it seems better to not include it even if lasso shrinks it

# %%
# drop X variables not used into models:
print(data.info())
data2 = data.drop(columns=['Source_mode','Name_mode','Name_710_131','Name_710_132','Name_710_135','Name_710_170','Name_711_083','Name_711_084','Colour_mode', 'Services', 'Season'])
print(data2.info())

# check again ranges of variables kept:
for i in data2.columns:
    print(data2[i].describe())
    print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Source_mode        580 non-null    category
#  1   Source_711_083     580 non-null    int64
#  2   Source_711_084     580 non-null    int64
#  3   Name_mode          580 non-null    category
#  4   Name_710_131       580 non-null    int64
#  5   Name_710_132       580 non-null    int64
#  6   Name_710_135       580 non-null    int64
#  7   Name_710_170       580 non-null    int64
#  8   Name_711_083       580 non-null    int64
#  9   Name_711_084       580 non-null    int64
#  10  Type_PDM           580 non-null    int64
#  11  Type_TRAIN_DRIVER  580 non-null    int64
#  12  Type_WARNING       580 non-null    int64
#  13  Speed_mean         580 non-null    float64
#  14  Criticality_mode   580 non-null    category
#  15  Colour_mode        580 non-null    category
#  16  Colour_azzurro     580 non-null    int64
#  17  Colour_giallo      580 non-null    int64
#  18  Season             580 non-null    category
#  19  Services           580 non-null    int64
#  20  Total_KM           580 non-null    float64
#  21  Sched_maint_progr  580 non-null    int64
#  22  Corr_maint_progr   580 non-null    int64
# dtypes: category(5), float64(2), int64(16)
# memory usage: 85.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Source_711_083     580 non-null    int64
#  1   Source_711_084     580 non-null    int64
#  2   Type_PDM           580 non-null    int64
#  3   Type_TRAIN_DRIVER  580 non-null    int64
#  4   Type_WARNING       580 non-null    int64
#  5   Speed_mean         580 non-null    float64
#  6   Criticality_mode   580 non-null    category
#  7   Colour_azzurro     580 non-null    int64
#  8   Colour_giallo      580 non-null    int64
#  9   Total_KM           580 non-null    float64
#  10  Sched_maint_progr  580 non-null    int64
#  11  Corr_maint_progr   580 non-null    int64
# dtypes: category(1), float64(2), int64(9)
# memory usage: 50.7 KB
# None
# count    580.000000
# mean      36.753448
# std       36.871802
# min        0.000000
# 25%       13.000000
# 50%       27.000000
# 75%       51.000000
# max      464.000000
# Name: Source_711_083, dtype: float64
#
#
# count    580.000000
# mean     102.256897
# std       65.874072
# min        0.000000
# 25%       59.750000
# 50%       95.000000
# 75%      131.250000
# max      513.000000
# Name: Source_711_084, dtype: float64
#
#
# count    580.000000
# mean     136.143103
# std       82.763257
# min        2.000000
# 25%       84.000000
# 50%      129.000000
# 75%      177.000000
# max      619.000000
# Name: Type_PDM, dtype: float64
#
#
# count    580.000000
# mean       0.634483
# std        1.273152
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max       15.000000
# Name: Type_TRAIN_DRIVER, dtype: float64
#
#
# count    580.000000
# mean       2.232759
# std        3.001317
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        3.000000
# max       26.000000
# Name: Type_WARNING, dtype: float64
#
#
# count    580.000000
# mean      26.884409
# std       11.014920
# min        0.000000
# 25%       19.951872
# 50%       26.074306
# 75%       34.020863
# max       71.890244
# Name: Speed_mean, dtype: float64
#
#
# count     580
# unique      2
# top         0
# freq      568
# Name: Criticality_mode, dtype: int64
#
#
# count    580.000000
# mean      96.613793
# std       61.378740
# min        0.000000
# 25%       57.000000
# 50%       90.000000
# 75%      127.250000
# max      546.000000
# Name: Colour_azzurro, dtype: float64
#
#
# count    580.000000
# mean      42.396552
# std       29.108361
# min        0.000000
# 25%       24.000000
# 50%       38.000000
# 75%       55.000000
# max      221.000000
# Name: Colour_giallo, dtype: float64
#
#
# count    580.000000
# mean     415.230690
# std      159.283198
# min        5.000000
# 25%      338.400000
# 50%      426.950000
# 75%      549.900000
# max      802.000000
# Name: Total_KM, dtype: float64
#
#
# count    580.000000
# mean      12.444828
# std        4.588646
# min        5.000000
# 25%        8.000000
# 50%       13.000000
# 75%       16.000000
# max       20.000000
# Name: Sched_maint_progr, dtype: float64
#
#
# count    580.000000
# mean      13.270690
# std        3.419062
# min        6.000000
# 25%       10.000000
# 50%       15.000000
# 75%       16.000000
# max       20.000000
# Name: Corr_maint_progr, dtype: float64

# %% [markdown]
# ### Analysis --> tuning parameters, fit, model evaluation:
#
# Given the set of predictors that comes from EDA, the following classifier will be considered: KNN, LDA, SVM, logistic, pruned decision tree, random forest, bagging, boosting
#
# The imbalance issue can be solved in 2 ways:
# - by applying techniques that tries to rebalance the dataset --> oversampling techniques will be applied to create new instances of the minority class: SMOTE and ADASYN
# - by doing the so called "threshold moving" --> cut off point is optimized on the imbalanced dataset
#
# Each classifier will be fitted on:
# - imbalanced dataset
# - rebalanced with SMOTE
# - rebalanced with ADASYN
# - imbalanced dataset + optimal threshold
#
# Tuning the parameters of each classifier and the parameters of SMOTE/ADASYN will be performed
#
# Steps are:
# - for each classifier find the "dataset" or threshold for which it performs better
# - find the overall best classifier (the best of the bests)
#
# and to do so, the following performance measures will be used: F1-score, sensitivity, specificity and AUC
#
# In order to perform all, a pipeline for each classifier will be build and implement

# %%
# Split into train and test set --> 70% and 30%:
x = data2.drop(columns=['Criticality_mode'])
y = data2['Criticality_mode']
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                   random_state=123,        # to reply results
                                   test_size=0.3,           # 70% train and 30% test
                                   shuffle=True)            # to shuffle data (otherwise it takes the first 70% of obs as train set --> no random)

# Standardize the dataset
scaler = StandardScaler()
x_train_sd = scaler.fit_transform(x_train)
x_test_sd = scaler.transform(x_test)            # .transform for test set in order to applies the same transformation from the training set

# %% [markdown]
# #### a) Logistic regression
#
# Lasso (penalty term l1) is implemented inside logistic regression algorithm and the parameter "C" is tuned

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score, roc_auc_score, confusion_matrix, make_scorer, roc_curve

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as Pipeline2

from imblearn.over_sampling import ADASYN

# %% [markdown]
# #### a1) Imbalanced dataset:

# %%
# %run -i 'a_Logistic_regression//a1_log_imb.py'
# Out:
# Tuning parameter:
# F1 score max: 0.3
# C tuned: 0.15000000000000002
#
# Model fitted:
# F1 Score: 0.000000
# Sensitivity (Recall): 0.000000
# Specificity: 1.000000
# AUC: 0.983432
#
# Features used in the model:
# Feature 1 (Coefficient: 0.0079)
# Feature 2 (Coefficient: -0.0139)
# Feature 3 (Coefficient: 0.0000)
# Feature 4 (Coefficient: 0.0000)
# Feature 5 (Coefficient: 0.0000)
# Feature 6 (Coefficient: 0.0000)
# Feature 7 (Coefficient: -0.1361)
# Feature 8 (Coefficient: 0.1309)
# Feature 9 (Coefficient: -0.0006)
# Feature 10 (Coefficient: 0.0000)
# Feature 11 (Coefficient: -0.1062)

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 6
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### a2) SMOTE rebelanced dataset:

# %%
# %run -i 'a_Logistic_regression//a2_log_smote.py'
# Out:
# Tuning parameter:
# F1 score max: 0.49333333333333335
# SMOTE k neighbors: 3
# Imbalance ratio: 0.4
# Logistic C: 0.25
# Criticality_mode
# 0    399
# 1    159
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.769231
# Sensitivity (Recall): 1.000000
# Specificity: 0.982249
# AUC: 0.985799
#
# Features used in the model:
# Feature 1 (Coefficient: 0.0052)
# Feature 2 (Coefficient: -0.0289)
# Feature 3 (Coefficient: 0.0000)
# Feature 4 (Coefficient: 0.0000)
# Feature 5 (Coefficient: 0.0000)
# Feature 6 (Coefficient: 0.0400)
# Feature 7 (Coefficient: -0.4160)
# Feature 8 (Coefficient: 0.3995)
# Feature 9 (Coefficient: 0.0011)
# Feature 10 (Coefficient: -0.0026)
# Feature 11 (Coefficient: 0.0000)

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 6
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### a3) ADASYN rebalanced dataset:

# %%
# %run -i 'a_Logistic_regression//a3_log_adasyn.py'
# Out:
# Tuning parameter:
# F1 score max: 0.5
# ADASYN n neighbors: 3
# Imbalance ratio: 0.4
# Logistic C: 0.15000000000000002
# Criticality_mode
# 0    399
# 1    161
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.769231
# Sensitivity (Recall): 1.000000
# Specificity: 0.982249
# AUC: 0.985799
#
# Features used in the model:
# Feature 1 (Coefficient: 0.0012)
# Feature 2 (Coefficient: -0.0287)
# Feature 3 (Coefficient: 0.0000)
# Feature 4 (Coefficient: 0.0000)
# Feature 5 (Coefficient: 0.0000)
# Feature 6 (Coefficient: 0.0368)
# Feature 7 (Coefficient: -0.3813)
# Feature 8 (Coefficient: 0.3737)
# Feature 9 (Coefficient: 0.0016)
# Feature 10 (Coefficient: -0.0226)
# Feature 11 (Coefficient: 0.0000)
# /opt/tljh/user/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 6
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### a4) Moving threshold:

# %%
# %run -i 'a_Logistic_regression//a4_log_mov_thresh.py'
# Out:
# /home/jupyter-giulia/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# Tuning parameter:
# F1 score max: 0.76
# C: 0.1
#
# Model fitted:
# Best threshold: 0.20400000000000001
# F1 Score: 0.800000
# Sensitivity (Recall): 0.800000
# Specificity: 0.994083
# AUC: 0.985799
#
# Features used in the model:
# Feature 1 (Coefficient: 0.0015)
# Feature 2 (Coefficient: -0.0175)
# Feature 3 (Coefficient: 0.0000)
# Feature 4 (Coefficient: 0.0000)
# Feature 5 (Coefficient: 0.0000)
# Feature 6 (Coefficient: 0.0000)
# Feature 7 (Coefficient: -0.1242)
# Feature 8 (Coefficient: 0.1281)
# Feature 9 (Coefficient: -0.0007)
# Feature 10 (Coefficient: 0.0000)
# Feature 11 (Coefficient: -0.0988)

# %%
#print(best_threshold)
#if round(best_threshold, 1) in thresholds_2:
#    print("yes")
#else:
#    print("no")
#print("\n")
index_thresh = np.where(thresholds_2 == round(best_threshold, 1))[0][0]
print(f"At threshold {thresholds_2[index_thresh]}: TPR = {tprs[index_thresh]} and FPR = {fprs[index_thresh]}")

plt.figure(figsize=(6.5, 6.5))
plt.plot(fprs, tprs, marker='.', label='ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', label='No skill')
plt.scatter(fprs[index_thresh], tprs[index_thresh], color='red', s=100)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Manually Specified Thresholds')
plt.legend()
plt.show()
# Out:
# At threshold 0.2: TPR = 0.8 and FPR = 0.011834319526627219

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 7
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### b) KNN
#
# K-nearest neighbors is fitted on standardized data and:
# - parameter "k" is tuned
# - different "weights" type are evaluated

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# #### b1) Imbalanced dataset:

# %%
# %run -i 'b_KNN//b1_knn_imb.py'
# Out:
# Tuning parameter:
# F1 score max: 0.0
# k: 1
# weight: uniform
#
# Model fitted:
# F1 Score: 0.000000
# Sensitivity (Recall): 0.000000
# Specificity: 0.982249
# AUC: -0.017751
# /opt/tljh/user/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 3
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### b2) SMOTE rebalanced dataset:

# %%
# %run -i 'b_KNN//b2_knn_smote.py'
# Out:
# Tuning parameter:
# F1 score max: 0.1
# SMOTE k neighbors: 4
# Imbalance ratio: 0.7999999999999999
# k: 1
# weight: uniform
# Criticality_mode
# 0    399
# 1    319
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.153846
# Sensitivity (Recall): 0.200000
# Specificity: 0.958580
# AUC: 0.158580
# /opt/tljh/user/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 3
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### b3) ADASYN rebalanced dataset:

# %%
# %run -i 'b_KNN//b3_knn_adasyn.py'
# Out:
# Tuning parameter:
# F1 score max: 0.1
# ADASYN n neighbors: 4
# Imbalance ratio: 0.4
# k: 2
# weight: uniform
# Criticality_mode
# 0    399
# 1    161
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.153846
# Sensitivity (Recall): 0.200000
# Specificity: 0.958580
# AUC: 0.326627

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 3
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### b4) Moving threshold:

# %%
# %run -i 'b_KNN//b4_knn_mov_thresh.py'
# Out:
# /home/jupyter-giulia/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# Tuning parameter:
# F1 score max: 0.08458329934469914
# k: 24
# weights: distance
#
# Model fitted:
# Best threshold: 0.038
# F1 Score: 0.206897
# Sensitivity (Recall): 0.600000
# Specificity: 0.875740
# AUC: 0.403550

# %%
#print(best_threshold)
#if round(best_threshold, 1) in thresholds_2:
#    print("yes")
#else:
#    print("no")
#print("\n")
index_thresh = np.where(thresholds_2 == round(best_threshold, 1))[0][0]
print(f"At threshold {thresholds_2[index_thresh]}: TPR = {tprs[index_thresh]} and FPR = {fprs[index_thresh]}")

plt.figure(figsize=(6.5, 6.5))
plt.plot(fprs, tprs, marker='.', label='ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', label='No skill')
plt.scatter(fprs[index_thresh], tprs[index_thresh], color='red', s=100)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Manually Specified Thresholds')
plt.legend()
plt.show()
# Out:
# At threshold 0.0: TPR = 1.0 and FPR = 1.0

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 1000
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### c) LDA
#
# Linear Discriminant Analysis is performed on standardized data without any tuning parameter procedure applied

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %% [markdown]
# #### c1) Imbalanced dataset:

# %%
# %run -i 'c_LDA//c1_lda_imb.py'
# Out:
# Model fitted:
# F1 Score: 0.000000
# Sensitivity (Recall): 0.000000
# Specificity: 0.994083
# AUC: 0.775148

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 13
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### c2) SMOTE rebalanced dataset:

# %%
# %run -i 'c_LDA//c2_lda_smote.py'
# Out:
# Tuning parameter:
# F1 score max: 0.18714285714285714
# SMOTE k neighbors: 4
# Imbalance ratio: 0.4
# Criticality_mode
# 0    399
# 1    159
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.444444
# Sensitivity (Recall): 0.800000
# Specificity: 0.946746
# AUC: 0.879290

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 13
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### c3) ADASYN rebalanced dataset:

# %%
# %run -i 'c_LDA//c3_lda_adasyn.py'
# Out:
# Tuning parameter:
# F1 score max: 0.18
# SMOTE k neighbors: 4
# Imbalance ratio: 0.4
# Criticality_mode
# 0    399
# 1    161
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.444444
# Sensitivity (Recall): 0.800000
# Specificity: 0.946746
# AUC: 0.815385

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 13
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### c4) Moving threshold:

# %%
# %run -i 'c_LDA//c4_lda_mov_thresh.py'
# Out:
# Model fitted:
# Best threshold: 0.023
# F1 Score: 0.400000
# Sensitivity (Recall): 0.800000
# Specificity: 0.934911
# AUC: 0.775148

# %%
#print(best_threshold)
#if round(best_threshold, 1) in thresholds_2:
#    print("yes")
#else:
#    print("no")
#print("\n")
index_thresh = np.where(thresholds_2 == round(best_threshold, 1))[0][0]
print(f"At threshold {thresholds_2[index_thresh]}: TPR = {tprs[index_thresh]} and FPR = {fprs[index_thresh]}")

plt.figure(figsize=(6.5, 6.5))
plt.plot(fprs, tprs, marker='.', label='ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', label='No skill')
plt.scatter(fprs[index_thresh], tprs[index_thresh], color='red', s=100)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Manually Specified Thresholds')
plt.legend()
plt.show()
# Out:
# At threshold 0.0: TPR = 1.0 and FPR = 1.0

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 1000
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### d) SVM
# Both linear and non-linear boundaries are considered by fitting SVC and SVM on standardized data, and the following hyperparameters are tuned:
# - C parameter --> budget (amount that the margin can be violated by n obs)
# - kernel: linear (SVC), polynomial and radial (SVM)
# - d parameter for polynomial kernel --> degree of the polyn.
# - gamma parameter for radial kernel --> how locally to look at
#
# (Values in parameter grid from Big data lab on SVM but degree of the polynomial =3 is not always considered due to the effort in finding the solution)

# %%
from sklearn.svm import SVC

# %% [markdown]
# #### d1) Imbalanced dataset:

# %%
# %run -i 'd_SVM//d1_svm_imb.py'
# Out:
# Tuning parameter:
# F1 score max: 0.13333333333333333
# {'C': 1, 'coef0': 0.0, 'degree': 3, 'kernel': 'poly'}
#
# Model fitted:
# F1 Score: 0.000000
# Sensitivity (Recall): 0.000000
# Specificity: 0.994083
# AUC: 0.813018

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 13
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### d2) SMOTE rebalanced dataset:

# %%
# %run -i 'd_SVM//d2_svm_smote.py'
# Out:
# Tuning parameter:
# F1 score max: 0.26666666666666666
# {'smote__k_neighbors': 3, 'smote__sampling_strategy': 0.4, 'svm__C': 10, 'svm__kernel': 'linear'}
# Criticality_mode
# 0    399
# 1    159
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.571429
# Sensitivity (Recall): 0.800000
# Specificity: 0.970414
# AUC: 0.962130
# /opt/tljh/user/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 11
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### d3) ADASYN rebalanced dataset:

# %%
# %run -i 'd_SVM//d3_svm_adasyn.py'
# Out:
# Tuning parameter:
# F1 score max: 0.3
# {'adasyn__n_neighbors': 3, 'adasyn__sampling_strategy': 0.4, 'svm__C': 5, 'svm__coef0': 0.5, 'svm__degree': 3, 'svm__kernel': 'poly'}
# Criticality_mode
# 0    399
# 1    161
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.000000
# Sensitivity (Recall): 0.000000
# Specificity: 0.970414
# AUC: 0.711243
# /opt/tljh/user/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 14
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### d4) Moving threshold:

# %%
# %run -i 'd_SVM//d4_svm_mov_thresh.py'
# Out:
# /home/jupyter-giulia/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# /opt/tljh/user/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Tuning parameter:
# F1 score max: 0.44080808080808076
# {'C': 0.001, 'kernel': 'linear'}
#
# Model fitted:
# Best threshold: 0.037
# F1 Score: 0.333333
# Sensitivity (Recall): 0.400000
# Specificity: 0.970414
# AUC: 0.353846

# %%
#print(best_threshold)
#if round(best_threshold, 1) in thresholds_2:
#    print("yes")
#else:
#    print("no")
#print("\n")
index_thresh = np.where(thresholds_2 == round(best_threshold, 1))[0][0]
print(f"At threshold {thresholds_2[index_thresh]}: TPR = {tprs[index_thresh]} and FPR = {fprs[index_thresh]}")

plt.figure(figsize=(6.5, 6.5))
plt.plot(fprs, tprs, marker='.', label='ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', label='No skill')
plt.scatter(fprs[index_thresh], tprs[index_thresh], color='red', s=100)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Manually Specified Thresholds')
plt.legend()
plt.show()
# Out:
# At threshold 0.0: TPR = 1.0 and FPR = 1.0

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 1000
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### e) Pruned decision tree
#
# Tree pruning is performed, which is that a very large tree is grown and then pruned it back in order to obtain a subtree through a penalty function
#
# So, cost complexity pruning is performend and tuning is performed on
# - alpha parameter
# - measure to choose the split

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %% [markdown]
# #### e1) Imbalanced dataset:

# %%
# %run -i 'e_Tree//e1_tree_imb.py'
# Out:
# Tuning parameter:
# F1 score max: 0.1
# criterion: gini
# alpha: 0.004
#
# Model fitted:
# F1 Score: 0.444444
# Sensitivity (Recall): 0.400000
# Specificity: 0.988166
# AUC: 0.391716

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 4
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### e2) SMOTE rebalanced dataset:

# %%
# %run -i 'e_Tree//e2_tree_smote.py'
# Out:
# Tuning parameter:
# F1 score max: 0.22222222222222224
# SMOTE k neighbors: 4
# Imbalance ratio: 0.7999999999999999
# criterion: entropy
# alpha: 0.011
# Criticality_mode
# 0    399
# 1    319
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.400000
# Sensitivity (Recall): 0.600000
# Specificity: 0.958580
# AUC: 0.861538

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 7
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### e3) ADASYN rebalanced dataset

# %%
# %run -i 'e_Tree//e3_tree_adasyn.py'
# Out:
# Tuning parameter:
# F1 score max: 0.26
# ADASYN n neighbors: 3
# Imbalance ratio: 0.5
# criterion: entropy
# alpha: 0.0
# Criticality_mode
# 0    399
# 1    196
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.500000
# Sensitivity (Recall): 0.600000
# Specificity: 0.976331
# AUC: 0.576331

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 3
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### e4) Moving threshold

# %%
#%run -i 'e_Tree//e4_tree_mov_thresh.py'

# %%
'''
#print(best_threshold)
#if round(best_threshold, 1) in thresholds_2:
#    print("yes")
#else:
#    print("no")
#print("\n")
index_thresh = np.where(thresholds_2 == round(best_threshold, 1))[0][0]
print(f"At threshold {thresholds_2[index_thresh]}: TPR = {tprs[index_thresh]} and FPR = {fprs[index_thresh]}")

plt.figure(figsize=(6.5, 6.5))
plt.plot(fprs, tprs, marker='.', label='ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', label='No skill')
plt.scatter(fprs[index_thresh], tprs[index_thresh], color='red', s=100)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Manually Specified Thresholds')
plt.legend()
plt.show()
'''
# Out:
# '\n#print(best_threshold)\n#if round(best_threshold, 1) in thresholds_2:\n#    print("yes")\n#else:\n#    print("no")\n#print("\n")\nindex_thresh = np.where(thresholds_2 == round(best_threshold, 1))[0][0]\nprint(f"At threshold {thresholds_2[index_thresh]}: TPR = {tprs[index_thresh]} and FPR = {fprs[index_thresh]}")\n\nplt.figure(figsize=(6.5, 6.5))\nplt.plot(fprs, tprs, marker=\'.\', label=\'ROC Curve\')\nplt.plot([0, 1], [0, 1], linestyle=\'--\', label=\'No skill\')\nplt.scatter(fprs[index_thresh], tprs[index_thresh], color=\'red\', s=100)\nplt.xlabel(\'False Positive Rate\')\nplt.ylabel(\'True Positive Rate\')\nplt.title(\'ROC Curve with Manually Specified Thresholds\')\nplt.legend()\nplt.show()\n'

# %%
'''
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
'''
# Out:
# '\n# extra)\n# a) what the function roc_curve does?\n#for i, threshold in enumerate(thresholds):\n    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")\n\nprint(len(thresholds))\n\n# b) manually computed:\nprint(f\'Number of thresholds: {len(thresholds_2)}\')\nprint(f\'Number of FPR values: {len(fprs)}\')\nprint(f\'Number of TPR values: {len(tprs)}\')\n#print(\'Thresholds:\', thresholds_2)\n#print(\'FPRs:\', fprs)\n#print(\'TPRs:\', tprs)\n'

# %% [markdown]
# #### f) Bagging classification tree:
#
# In order to avoid overfitting and reduce the high variance of decision trees estimates, boostrap aggregation is applied and OOB estimation for classification error is performed. There isn't any tuning parameter for bagging

# %%
from sklearn.ensemble import BaggingClassifier

# %% [markdown]
# #### f1) Imbalanced dataset:

# %%
# %run -i 'f_Bagging//f1_bagg_imb.py'
# Out:
# Model fitted:
# F1 Score: 0.333333
# Sensitivity (Recall): 0.200000
# Specificity: 1.000000
# AUC: 0.485207

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 10
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### f2) SMOTE rebalanced dataset:

# %%
# %run -i 'f_Bagging//f2_bagg_smote.py'
# Out:
# Tuning parameter:
# F1 score max: 0.2
# SMOTE k neighbors: 4
# Imbalance ratio: 0.5
# Criticality_mode
# 0    399
# 1    199
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.727273
# Sensitivity (Recall): 0.800000
# Specificity: 0.988166
# AUC: 0.965680

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 25
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### f3) ADASYN rebalanced dataset:

# %%
# %run -i 'f_Bagging//f3_bagg_adasyn.py'
# Out:
# Tuning parameter:
# F1 score max: 0.2
# ADASYN n neighbors: 3
# Imbalance ratio: 0.7
# Criticality_mode
# 0    399
# 1    280
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.400000
# Sensitivity (Recall): 0.400000
# Specificity: 0.982249
# AUC: 0.936095

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 28
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### f4) Moving threshold:

# %%
# %run -i 'f_Bagging//f4_bagg_mov_thresh.py'
# Out:
# Model fitted:
# F1 Score: 0.444444
# Sensitivity (Recall): 0.400000
# Specificity: 0.988166
# AUC: 0.485207

# %%
#print(best_threshold)
#if round(best_threshold, 1) in thresholds_2:
#    print("yes")
#else:
#    print("no")
#print("\n")
index_thresh = np.where(thresholds_2 == round(best_threshold, 1))[0][0]
print(f"At threshold {thresholds_2[index_thresh]}: TPR = {tprs[index_thresh]} and FPR = {fprs[index_thresh]}")

plt.figure(figsize=(6.5, 6.5))
plt.plot(fprs, tprs, marker='.', label='ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', label='No skill')
plt.scatter(fprs[index_thresh], tprs[index_thresh], color='red', s=100)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Manually Specified Thresholds')
plt.legend()
plt.show()
# Out:
# At threshold 0.4: TPR = 0.4 and FPR = 0.011834319526627219

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 10
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### g) Random Forest
#
# In bagging trees are very correlated and it can happen that there are predictors that dominate all the trees because they are very very important, and so it can happen that all the tree are pretty identical.
#
# An improvement can be reached by using a subset of predictors for each split when the decision trees are built, which is random forest. In this case tuning of the following parameter is done:
# - n. of predictors to consider at each split --> max_features
# - minimum size node --> min_samples_leaf

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### g1) Imbalanced dataset:

# %%
# %run -i 'g_RandomForest//g1_randfor_imb.py'
# Out:
# Tuning parameter:
# F1 score max: 0.0
# max n. predictors: 2
# min size node: 1
#
# Model fitted:
# F1 Score: 0.333333
# Sensitivity (Recall): 0.200000
# Specificity: 1.000000
# AUC: 0.835503

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 22
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### g2) SMOTE rebalanced dataset:

# %%
# %run -i 'g_RandomForest//g2_randfor_smote.py'
# Out:
# /opt/tljh/user/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Tuning parameter:
# F1 score max: 0.2
# SMOTE k neighbors: 3
# Imbalance ratio: 0.5
# max n. predictors: 2
# min size node: 1
# Criticality_mode
# 0    399
# 1    199
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.500000
# Sensitivity (Recall): 0.400000
# Specificity: 0.994083
# AUC: 0.879290

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 41
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### g3) ADASYN rebalanced dataset:

# %%
# %run -i 'g_RandomForest//g3_randfor_adasyn.py'
# Out:
# /opt/tljh/user/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Tuning parameter:
# F1 score max: 0.2
# ADASYN n neighbors: 3
# Imbalance ratio: 0.4
# max n. predictors: 2
# min size node: 2
# Criticality_mode
# 0    399
# 1    161
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.444444
# Sensitivity (Recall): 0.400000
# Specificity: 0.988166
# AUC: 0.884024

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 18
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### g4) Moving threshold:

# %%
# %run -i 'g_RandomForest//g4_randfor_mov_thresh.py'
# Out:
# /home/jupyter-giulia/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# F1 score max: 0.5715447154471545
# {'max_features': 6, 'min_samples_leaf': 2}
# max n. predictors: 6
# min size node: 2
#
# Model fitted:
# F1 Score: 0.500000
# Sensitivity (Recall): 0.400000
# Specificity: 0.994083
# AUC: 0.582249

# %%
#print(best_threshold)
#if round(best_threshold, 1) in thresholds_2:
#    print("yes")
#else:
#    print("no")
#print("\n")
index_thresh = np.where(thresholds_2 == round(best_threshold, 1))[0][0]
print(f"At threshold {thresholds_2[index_thresh]}: TPR = {tprs[index_thresh]} and FPR = {fprs[index_thresh]}")

plt.figure(figsize=(6.5, 6.5))
plt.plot(fprs, tprs, marker='.', label='ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', label='No skill')
plt.scatter(fprs[index_thresh], tprs[index_thresh], color='red', s=100)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Manually Specified Thresholds')
plt.legend()
plt.show()
# Out:
# At threshold 0.3: TPR = 0.4 and FPR = 0.01775147928994083

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 22
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### h) Boosting
#
# Bagging can be improved without using bootstrap. In boosting trees, that are then aggregated, are grown sequentially --> they are not independent because each tree is built on the residuals of the previous tree.
#
# The following parameters are tuned:
# - n_estimators --> number of trees (B)
# - learning_rate --> shrinkage parameter (lambda)
# - max_depth in the decisiontree --> number of splits in each tree / depth of each tree (d)
#
# (Parameter grid from Big data lab)

# %%
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# #### h1) Imbalanced dataset:

# %%
# %run -i 'h_Boosting//h1_boost_imb.py'
# Out:
# Tuning parameter:
# F1 score max: 0.1
# depth tree: 1
# learning rate: 0.01
# n. trees: 10
#
# Model fitted:
# F1 Score: 0.400000
# Sensitivity (Recall): 0.400000
# Specificity: 0.982249
# AUC: 0.382249

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 3
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### h2) SMOTE rebalanced dataset:

# %%
# %run -i 'h_Boosting//h2_boost_smote.py'
# Out:
# /opt/tljh/user/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Tuning parameter:
# F1 score max: 0.32272727272727275
# {'boost__estimator__max_depth': 4, 'boost__learning_rate': 0.01, 'boost__n_estimators': 50, 'smote__k_neighbors': 4, 'smote__sampling_strategy': 0.6}
# SMOTE k neighbors: 4
# Imbalance ratio: 0.6
# depth tree: 4
# learning rate: 0.01
# n. trees: 50
# Criticality_mode
# 0    399
# 1    239
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.240000
# Sensitivity (Recall): 0.600000
# Specificity: 0.899408
# AUC: 0.867456

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 23
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### h3) ADASYN rebalanced dataset:

# %%
# %run -i 'h_Boosting//h3_boost_adasyn.py'
# Out:
# Tuning parameter:
# F1 score max: 0.2333333333333333
# ADASYN n neighbors: 3
# Imbalance ratio: 0.5
# depth tree: 3
# learning rate: 0.03
# n. trees: 70
# Criticality_mode
# 0    399
# 1    196
# Name: count, dtype: int64
#
# Model fitted:
# F1 Score: 0.315789
# Sensitivity (Recall): 0.600000
# Specificity: 0.934911
# AUC: 0.936095
# /opt/tljh/user/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 32
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %% [markdown]
# #### h4) Moving threshold

# %%
# %run -i 'h_Boosting//h4_boost_mov_thresh.py'
# Out:
# /home/jupyter-giulia/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# Tuning parameter:
# F1 score max: 0.4882113821138211
# depth tree: 3
# learning rate: 0.060000000000000005
# n. trees: 40
#
# Model fitted:
# F1 Score: 0.571429
# Sensitivity (Recall): 0.400000
# Specificity: 1.000000
# AUC: 0.491124

# %%
#print(best_threshold)
#if round(best_threshold, 1) in thresholds_2:
#    print("yes")
#else:
#    print("no")
#print("\n")
index_thresh = np.where(thresholds_2 == round(best_threshold, 1))[0][0]
print(f"At threshold {thresholds_2[index_thresh]}: TPR = {tprs[index_thresh]} and FPR = {fprs[index_thresh]}")

plt.figure(figsize=(6.5, 6.5))
plt.plot(fprs, tprs, marker='.', label='ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', label='No skill')
plt.scatter(fprs[index_thresh], tprs[index_thresh], color='red', s=100)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with Manually Specified Thresholds')
plt.legend()
plt.show()
# Out:
# At threshold 0.5: TPR = 0.4 and FPR = 0.0

# %%
# extra)
# a) what the function roc_curve does?
#for i, threshold in enumerate(thresholds):
    #print(f"Threshold: {threshold:.4f}, TPR: {tpr[i]:.4f}, FPR: {fpr[i]:.4f}")

print(len(thresholds))

# b) manually computed:
print(f'Number of thresholds: {len(thresholds_2)}')
print(f'Number of FPR values: {len(fprs)}')
print(f'Number of TPR values: {len(tprs)}')
#print('Thresholds:', thresholds_2)
#print('FPRs:', fprs)
#print('TPRs:', tprs)
# Out:
# 8
# Number of thresholds: 101
# Number of FPR values: 101
# Number of TPR values: 101

# %%
'''
# 4) MOVING THRESHOLD:
from sklearn.base import BaseEstimator, ClassifierMixin

# a) Define functions
# Custom classifier that allows for threshold adjustment
class ThresholdClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, estimator=None, threshold=0.5):
        self.estimator = estimator
        self.threshold = threshold

    def fit(self, X, y):
        self.estimator.fit(X, y)
        self.classes_ = self.estimator.classes_
        return self

    def predict(self, X):
        proba = self.estimator.predict_proba(X)[:, 1]
        return (proba >= self.threshold).astype(int)

    def predict_proba(self, X):
        return self.estimator.predict_proba(X)

    def get_params(self, deep=True):
        return {
            'estimator': self.estimator,
            'threshold': self.threshold
        }

    def set_params(self, **params):
        if 'estimator' in params:
            self.estimator = params.pop('estimator')
        if 'threshold' in params:
            self.threshold = params.pop('threshold')
        return self

logistic = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000)

# b) Define parameter grid
param_grid = {
    'estimator__C': np.arange(0.05, 2, 0.05),                # Tuning C for Lasso Logistic Regression
    'threshold': np.arange(0.05, 1.05, 0.05)         # Tuning the decision threshold
}
f1_scorer = make_scorer(f1_score)

# c) Grid search
grid_search = GridSearchCV(ThresholdClassifier(estimator=logistic), param_grid, cv=cv, scoring=f1_scorer, n_jobs=-1, refit=False, error_score='raise')
result_tuning = grid_search.fit(x_train, y_train)
# check value of hyperparameters:
print("Tuning parameter:")
print(f"F1 score max: {result_tuning.best_score_}")
#print(result_tuning.best_params_)
tuned_par = list(result_tuning.best_params_.values())
print(f"C: {tuned_par[0]}")
print(f"Threshold: {tuned_par[1]}")

# d) fit logistic with tuned parameters
logistic_tuned = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000, C=tuned_par[0])
log_fit = logistic_tuned.fit(x_train, y_train)

# e) Predict on the test set
# Define a function to apply a custom threshold
def apply_threshold(proba, threshold=0.5):
    return (proba >= threshold).astype(int)

y_prob = log_fit.predict_proba(x_test)[:, 1]    # predicted prob for positive class
y_pred = apply_threshold(y_prob, threshold=tuned_par[1])

# f) Calculate performance metrics: f1 score, sensitivity, specificity, auc
f1 = f1_score(y_test, y_pred)
fpr, tpr, _ = roc_curve(y_test,  y_prob)
auc = roc_auc_score(y_test, y_prob)
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# g) Print out the results
print("\nModel fitted:")
print(f"F1 Score: {f1:.6f}")
print(f"Sensitivity (Recall): {sensitivity:.6f}")
print(f"Specificity: {specificity:.6f}")
print(f"AUC: {auc:.6f}")

coefficients = log_fit.coef_[0]
non_zero_coefficients = coefficients != 0
used_features = np.array(non_zero_coefficients)

print("Features used in the model:")
for i, is_used in enumerate(non_zero_coefficients):
    if is_used:
        print(f"Feature {i+1} (Coefficient: {coefficients[i]:.4f})")
    else:
        print(f"Feature {i+1} (Coefficient: {coefficients[i]:.4f})")

# h) Plot roc curve:
plt.plot(fpr,tpr,label="auc="+str(auc))
plt.legend(loc=4)
plt.show()
'''
# Out:
# '\n# 4) MOVING THRESHOLD:\nfrom sklearn.base import BaseEstimator, ClassifierMixin\n\n# a) Define functions\n# Custom classifier that allows for threshold adjustment\nclass ThresholdClassifier(BaseEstimator, ClassifierMixin):\n    def __init__(self, estimator=None, threshold=0.5):\n        self.estimator = estimator\n        self.threshold = threshold\n\n    def fit(self, X, y):\n        self.estimator.fit(X, y)\n        self.classes_ = self.estimator.classes_\n        return self\n\n    def predict(self, X):\n        proba = self.estimator.predict_proba(X)[:, 1]\n        return (proba >= self.threshold).astype(int)\n\n    def predict_proba(self, X):\n        return self.estimator.predict_proba(X)\n\n    def get_params(self, deep=True):\n        return {\n            \'estimator\': self.estimator,\n            \'threshold\': self.threshold\n        }\n\n    def set_params(self, **params):\n        if \'estimator\' in params:\n            self.estimator = params.pop(\'estimator\')\n        if \'threshold\' in params:\n            self.threshold = params.pop(\'threshold\')\n        return self\n\nlogistic = LogisticRegression(penalty=\'l1\', solver=\'liblinear\', max_iter=1000)\n\n# b) Define parameter grid\nparam_grid = {\n    \'estimator__C\': np.arange(0.05, 2, 0.05),                # Tuning C for Lasso Logistic Regression\n    \'threshold\': np.arange(0.05, 1.05, 0.05)         # Tuning the decision threshold\n}\nf1_scorer = make_scorer(f1_score)\n\n# c) Grid search\ngrid_search = GridSearchCV(ThresholdClassifier(estimator=logistic), param_grid, cv=cv, scoring=f1_scorer, n_jobs=-1, refit=False, error_score=\'raise\')\nresult_tuning = grid_search.fit(x_train, y_train)\n# check value of hyperparameters:\nprint("Tuning parameter:")\nprint(f"F1 score max: {result_tuning.best_score_}")\n#print(result_tuning.best_params_)\ntuned_par = list(result_tuning.best_params_.values())\nprint(f"C: {tuned_par[0]}")\nprint(f"Threshold: {tuned_par[1]}")\n\n# d) fit logistic with tuned parameters\nlogistic_tuned = LogisticRegression(penalty=\'l1\', solver=\'liblinear\', max_iter=1000, C=tuned_par[0])\nlog_fit = logistic_tuned.fit(x_train, y_train)\n\n# e) Predict on the test set\n# Define a function to apply a custom threshold\ndef apply_threshold(proba, threshold=0.5):\n    return (proba >= threshold).astype(int)\n\ny_prob = log_fit.predict_proba(x_test)[:, 1]    # predicted prob for positive class\ny_pred = apply_threshold(y_prob, threshold=tuned_par[1])\n\n# f) Calculate performance metrics: f1 score, sensitivity, specificity, auc\nf1 = f1_score(y_test, y_pred)\nfpr, tpr, _ = roc_curve(y_test,  y_prob)\nauc = roc_auc_score(y_test, y_prob)\ntn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()\nsensitivity = tp / (tp + fn)\nspecificity = tn / (tn + fp)\n\n# g) Print out the results\nprint("\nModel fitted:")\nprint(f"F1 Score: {f1:.6f}")\nprint(f"Sensitivity (Recall): {sensitivity:.6f}")\nprint(f"Specificity: {specificity:.6f}")\nprint(f"AUC: {auc:.6f}")\n\ncoefficients = log_fit.coef_[0]\nnon_zero_coefficients = coefficients != 0\nused_features = np.array(non_zero_coefficients)\n\nprint("Features used in the model:")\nfor i, is_used in enumerate(non_zero_coefficients):\n    if is_used:\n        print(f"Feature {i+1} (Coefficient: {coefficients[i]:.4f})")\n    else:\n        print(f"Feature {i+1} (Coefficient: {coefficients[i]:.4f})")\n\n# h) Plot roc curve:\nplt.plot(fpr,tpr,label="auc="+str(auc))\nplt.legend(loc=4)\nplt.show()\n'

# %%
'''
# single logistic regression for each predictor:
#!pip install scikit-learn
from sklearn.linear_model import LogisticRegression

# a) define predictors and dependent variable:
x = data.drop('Criticality_mode', axis=1)
y = data['Criticality_mode']

# b) instantiate the model:
logreg = LogisticRegression(penalty=None,
                            class_weight='balanced',    #The “balanced” mode uses the values of y to automatically adjust weights inversely proportional to class frequencies in the input data as n_samples / (n_classes * np.bincount(y))
                            solver='newton-cholesky',   #‘newton-cholesky’ is a good choice for n_samples >> n_features, especially with one-hot encoded categorical features with rare categories. Be aware that the memory usage of this solver has a quadratic dependency on n_features because it explicitly computes the Hessian matrix
                            )
'''
# Out:
# "\n# single logistic regression for each predictor:\n#!pip install scikit-learn\nfrom sklearn.linear_model import LogisticRegression\n\n# a) define predictors and dependent variable:\nx = data.drop('Criticality_mode', axis=1)\ny = data['Criticality_mode']\n\n# b) instantiate the model:\nlogreg = LogisticRegression(penalty=None,\n                            class_weight='balanced',    #The “balanced” mode uses the values of y to automatically adjust weights inversely proportional to class frequencies in the input data as n_samples / (n_classes * np.bincount(y))\n                            solver='newton-cholesky',   #‘newton-cholesky’ is a good choice for n_samples >> n_features, especially with one-hot encoded categorical features with rare categories. Be aware that the memory usage of this solver has a quadratic dependency on n_features because it explicitly computes the Hessian matrix\n                            )\n"

# %%
'''
# c) encoding categorical variables as k-1 dummy variables (k=n. of classes):
# first of all categorical variables need to be preprocessed because scikitlearn handles categorical features only if encoded as k dummy variables:
print(x_cat)
for i in x_cat:
       print(data[i].value_counts())

data_encoded = pd.get_dummies(data, columns=['Source_mode', 'Colour_mode', 'Season'], drop_first=True)
data_encoded2 = pd.get_dummies(data_encoded, columns=['Name_mode'])
print(data_encoded2.info())
data_encoded3 = data_encoded2.drop(columns=['Name_mode_710-000', 'Name_mode_710-131'])
print(data_encoded3.info())

enc_var = data_encoded3.columns[19:29]
print(enc_var)

for i in enc_var:
       data_encoded3[i] = data_encoded3[i].astype('int64')

data_encoded3['Criticality_mode'] = data_encoded3['Criticality_mode'].astype('int64')
print(data_encoded3.info())
'''
# Out:
# "\n# c) encoding categorical variables as k-1 dummy variables (k=n. of classes):\n# first of all categorical variables need to be preprocessed because scikitlearn handles categorical features only if encoded as k dummy variables:\nprint(x_cat)\nfor i in x_cat:\n       print(data[i].value_counts())\n\ndata_encoded = pd.get_dummies(data, columns=['Source_mode', 'Colour_mode', 'Season'], drop_first=True)\ndata_encoded2 = pd.get_dummies(data_encoded, columns=['Name_mode'])\nprint(data_encoded2.info())\ndata_encoded3 = data_encoded2.drop(columns=['Name_mode_710-000', 'Name_mode_710-131'])\nprint(data_encoded3.info())\n\nenc_var = data_encoded3.columns[19:29]\nprint(enc_var)\n\nfor i in enc_var:\n       data_encoded3[i] = data_encoded3[i].astype('int64')\n\ndata_encoded3['Criticality_mode'] = data_encoded3['Criticality_mode'].astype('int64')\nprint(data_encoded3.info())\n"

# %%
'''
x = data_encoded3[['Source_711-083']]
y = data_encoded3['Criticality_mode']
try1 = logreg.fit(x, y)
print(try1.coef_)

#!pip install statsmodels
import statsmodels.api as sm
log_reg = sm.Logit(y, x).fit()
print(log_reg.summary())
print(log_reg.pvalues)      # H0: population coefficient is zero
'''
# Out:
# "\nx = data_encoded3[['Source_711-083']]\ny = data_encoded3['Criticality_mode']\ntry1 = logreg.fit(x, y)\nprint(try1.coef_)\n\n#!pip install statsmodels\nimport statsmodels.api as sm\nlog_reg = sm.Logit(y, x).fit()\nprint(log_reg.summary())\nprint(log_reg.pvalues)      # H0: population coefficient is zero\n"

# %%
'''
log_reg = sm.Logit(data['Criticality_mode'], data['Source_mode']).fit()
print(log_reg.summary())
print(log_reg.pvalues)
'''
# Out:
# "\nlog_reg = sm.Logit(data['Criticality_mode'], data['Source_mode']).fit()\nprint(log_reg.summary())\nprint(log_reg.pvalues)\n"

# %%
'''

# d) fit the model:

x = data_encoded3.drop('Criticality_mode', axis=1)
y = data_encoded3['Criticality_mode']

for predictor in x:
       logreg.fit(predictor, y)
'''
# Out:
# "\n\n# d) fit the model:\n\nx = data_encoded3.drop('Criticality_mode', axis=1)\ny = data_encoded3['Criticality_mode']\n\nfor predictor in x:\n       logreg.fit(predictor, y)\n"

# %%
# da scartare

'''
# Y and numerical predictors:
x_num_1 = ['Source_711-083', 'Source_711-084', 'Name_710-131', 'Name_710-132', 'Name_710-135', 'Name_710-170',
       'Name_711-083', 'Name_711-084']
x_num_2 = ['Type_PDM', 'Type_TRAIN_DRIVER', 'Type_WARNING', 'Speed_mean', 'Colour_azzurro', 'Colour_giallo']
x_num_3 = ['Services', 'Total_KM', 'Sched_maint_progr', 'Corr_maint_progr']
x_num = ['Source_711-083', 'Source_711-084', 'Name_710-131', 'Name_710-132', 'Name_710-135', 'Name_710-170',
       'Name_711-083', 'Name_711-084', 'Type_PDM', 'Type_TRAIN_DRIVER', 'Type_WARNING', 'Speed_mean', 'Colour_azzurro', 'Colour_giallo',
       'Services', 'Total_KM', 'Sched_maint_progr', 'Corr_maint_progr']
# 1)
sns.pairplot(data, vars=x_num_1, hue='Criticality_mode')
sns.pairplot(data, vars=x_num_2, hue='Criticality_mode')
sns.pairplot(data, vars=x_num_3, hue='Criticality_mode')
'''
# Out:
# "\n# Y and numerical predictors:\nx_num_1 = ['Source_711-083', 'Source_711-084', 'Name_710-131', 'Name_710-132', 'Name_710-135', 'Name_710-170',\n       'Name_711-083', 'Name_711-084']\nx_num_2 = ['Type_PDM', 'Type_TRAIN_DRIVER', 'Type_WARNING', 'Speed_mean', 'Colour_azzurro', 'Colour_giallo']\nx_num_3 = ['Services', 'Total_KM', 'Sched_maint_progr', 'Corr_maint_progr']\nx_num = ['Source_711-083', 'Source_711-084', 'Name_710-131', 'Name_710-132', 'Name_710-135', 'Name_710-170',\n       'Name_711-083', 'Name_711-084', 'Type_PDM', 'Type_TRAIN_DRIVER', 'Type_WARNING', 'Speed_mean', 'Colour_azzurro', 'Colour_giallo',\n       'Services', 'Total_KM', 'Sched_maint_progr', 'Corr_maint_progr']\n# 1)\nsns.pairplot(data, vars=x_num_1, hue='Criticality_mode')\nsns.pairplot(data, vars=x_num_2, hue='Criticality_mode')\nsns.pairplot(data, vars=x_num_3, hue='Criticality_mode')\n"
